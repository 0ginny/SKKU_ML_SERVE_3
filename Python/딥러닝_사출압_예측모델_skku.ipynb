# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/skku_python_repo-main/08. 유형별로 실습하는 딥러닝
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/skku_python_repo-main/08. 유형별로 실습하는 딥러닝

# %% [markdown]
# # 모델 불러오기

# %%
import pickle
from tensorflow.keras.models import load_model
import pandas as pd

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/skku_python_repo-main/08. 유형별로 실습하는 딥러닝

# %%
with open("./models/Injection_Pressure.dump","rb") as fr:
    loadedRef = pickle.load(fr)
# 0:feature 1: labels 2: preprocessing
# loadedRef

# %%
loadedModel = load_model("./models/Injection_Pressure.h5")

# %%
loadedModel.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 8)                 32
#
#  dense_19 (Dense)            (None, 8)                 72
#
#  dense_20 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 113 (452.00 Byte)
# Trainable params: 113 (452.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loadedRef
# Out:
# {'temperature': ['RESIN_TEMPERATURE', 'MOLD_TEMPERATURE', 'INJECTION_TIME'],
#  'orgtemperaturet': ['RESIN_TEMPERATURE',
#   'MOLD_TEMPERATURE',
#   'INJECTION_TIME'],
#  'label': ['INJECTION_PRESSURE'],
#  'model': <keras.src.engine.sequential.Sequential at 0x7dbb8cdf3d90>}

# %%
# preProcessingFunc = loadedRef["preprocessing"]

# %%
# 화면입력데이터 변수 할당
inResinTemp = 223
inMoldTemp = 49
inTime = 1.9

# %%
# # 전처리 함수 불러오기
# ynLabel = preProcessingFunc[0]
# promotionScaler = preProcessingFunc[2]
# hclusScaler = preProcessingFunc[3]

# %%
# # 입력데이터 전처리
# inPromotionCvt = ynLabel.transform( [inPromotion] )[0]
# inHolidayCvt = ynLabel.transform( [inHoliday] )[0]
# inPropercentCvt = promotionScaler.transform( [[inPropercent]] )[0][0]
# inHclusCvt = hclusScaler.transform( [[inHclus]] )[0][0]

# %%
# 예측을 위한 데이터셋 생성
TemperatureData = pd.DataFrame( [[ inResinTemp, inMoldTemp, inTime ]] )

# %%
# 예측
predictValue = loadedModel.predict( TemperatureData)[0][0]
# Out:
# 1/1 [==============================] - 0s 69ms/step
